# %% [markdown]
# ### For taking images of my chessboard

# %%
import cv2
import os
import re

# Create folder to save images
save_dir = "../calibration_images"
os.makedirs(save_dir, exist_ok=True)

# --------- NEW: Determine starting image index ----------
existing_files = os.listdir(save_dir)

image_numbers = []

for file in existing_files:
    match = re.match(r"image_(\d+)\.jpg", file)
    if match:
        image_numbers.append(int(match.group(1)))

if image_numbers:
    img_count = max(image_numbers) + 1
else:
    img_count = 0
# --------------------------------------------------------

# Open default camera
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

print(f"Starting from image index: {img_count}")
print("Press 's' to save image")
print("Press 'q' to quit")

while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break

    cv2.imshow("Camera", frame)

    key = cv2.waitKey(1) & 0xFF

    if key == ord('s'):
        img_name = os.path.join(save_dir, f"image_{img_count}.jpg")
        cv2.imwrite(img_name, frame)
        print(f"Saved {img_name}")
        img_count += 1

    elif key == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Starting from image index: 0
# Press 's' to save image
# Press 'q' to quit
# Saved calibration_images\image_0.jpg
# Saved calibration_images\image_1.jpg
# Saved calibration_images\image_2.jpg
# Saved calibration_images\image_3.jpg
# Saved calibration_images\image_4.jpg
# Saved calibration_images\image_5.jpg
# Saved calibration_images\image_6.jpg
# Saved calibration_images\image_7.jpg
# Saved calibration_images\image_8.jpg
# Saved calibration_images\image_9.jpg
# Saved calibration_images\image_10.jpg
# Saved calibration_images\image_11.jpg
# Saved calibration_images\image_12.jpg
# Saved calibration_images\image_13.jpg
# Saved calibration_images\image_14.jpg
# Saved calibration_images\image_15.jpg
# Saved calibration_images\image_16.jpg
# Saved calibration_images\image_17.jpg
# Saved calibration_images\image_18.jpg
# Saved calibration_images\image_19.jpg
# Saved calibration_images\image_20.jpg
